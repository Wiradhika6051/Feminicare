# %% [markdown]
# ## Chatbot

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer 
import pandas as pd
import string
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %%
import json

# Load the dataset from a JSON file
with open('dataset2.json') as f:
    data = json.load(f)


stop_words = set()

with open('stopword_id.txt', 'r', encoding='utf-8') as file:
    for line in file:
        stop_words.add(line.strip())


tags = []
inputs = []
responses = {}
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

for intent in data['intents']:
    responses[intent['tag']] = intent['responses']
    for line in intent['patterns']:
        # Tokenize each word in the pattern
        w = nltk.word_tokenize(line)
        w = [lemmatizer.lemmatize(stemmer.stem(word.lower())) for word in w if word not in stop_words]
        inputs.append(' '.join(w))
        tags.append(intent['tag'])

# Create a DataFrame
data_df = pd.DataFrame({"inputs": inputs, "tags": tags})

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# Tokenizer
tokenizer = Tokenizer(num_words=2000, oov_token='<OOV>')
tokenizer.fit_on_texts(data_df['inputs'])

# Encode the outputs
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(data_df['tags'])

# Define input shape
input_shape = 100  # Misalkan panjang maksimum input adalah 100 kata

# Padding sequences
sequences = tokenizer.texts_to_sequences(data_df['inputs'])
x_train = pad_sequences(sequences, maxlen=input_shape, truncating='post')

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
model = Sequential([
    tf.keras.layers.Embedding(len(tokenizer.word_index)+1, 64, input_length=100),
    tf.keras.layers.LSTM(10, return_sequences=True),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(len(y_train), activation='softmax'),
])
# compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 2s 27ms/step - loss: 5.2271 - accuracy: 0.0000e+00
# Epoch 2/200
# 7/7 [==============================] - 0s 26ms/step - loss: 4.6347 - accuracy: 0.0245
# Epoch 3/200
# 7/7 [==============================] - 0s 26ms/step - loss: 4.2021 - accuracy: 0.0147
# Epoch 4/200
# 7/7 [==============================] - 0s 28ms/step - loss: 4.1383 - accuracy: 0.0392
# Epoch 5/200
# 7/7 [==============================] - 0s 26ms/step - loss: 4.1219 - accuracy: 0.0392
# Epoch 6/200
# 7/7 [==============================] - 0s 27ms/step - loss: 4.1031 - accuracy: 0.0196
# Epoch 7/200
# 7/7 [==============================] - 0s 26ms/step - loss: 4.1003 - accuracy: 0.0196
# Epoch 8/200
# 7/7 [==============================] - 0s 29ms/step - loss: 4.0841 - accuracy: 0.0490
# Epoch 9/200
# 7/7 [==============================] - 0s 29ms/step - loss: 4.0815 - accuracy: 0.0294
# Epoch 10/200
# 7/7 [==============================] - 0s 29ms/step - loss: 4.0674 - accuracy: 0.0392
# Epoch 11/200
# 7/7 [==============================] - 0s 28ms/step - loss: 4.0583 - accuracy: 0.0392
# Epoch 12/200
# 7/7 [==============================] - 0s 28ms/step - loss: 4.0584 - accuracy: 0.0392
# Epoch 13/200
# 7/7 [==============================] - 0s 27ms/step - loss: 4.0483 - accuracy: 0.0833
# Epoch 14/200
# 7/7 [==============================] - 0s 27ms/step - loss: 4.0435 - accuracy: 0.0343
# Epoch 15/200
# 7/7 [==============================] - 0s 31ms/step - loss: 4.0252 - accuracy: 0.0833
# Epoch 16/200
# 7/7 [==============================] - 0s 28ms/step - loss: 4.0098 - accuracy: 0.0637
# Epoch 17/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.9961 - accuracy: 0.0637
# Epoch 18/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.9849 - accuracy: 0.0588
# Epoch 19/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.9642 - accuracy: 0.0686
# Epoch 20/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.9374 - accuracy: 0.0441
# Epoch 21/200
# 7/7 [==============================] - 0s 32ms/step - loss: 3.9155 - accuracy: 0.0490
# Epoch 22/200
# 7/7 [==============================] - 0s 28ms/step - loss: 3.8825 - accuracy: 0.0931
# Epoch 23/200
# 7/7 [==============================] - 0s 31ms/step - loss: 3.8510 - accuracy: 0.1225
# Epoch 24/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.8182 - accuracy: 0.0931
# Epoch 25/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.7943 - accuracy: 0.1373
# Epoch 26/200
# 7/7 [==============================] - 0s 29ms/step - loss: 3.7418 - accuracy: 0.1569
# Epoch 27/200
# 7/7 [==============================] - 0s 28ms/step - loss: 3.6824 - accuracy: 0.1716
# Epoch 28/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.6205 - accuracy: 0.1618
# Epoch 29/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.5706 - accuracy: 0.1373
# Epoch 30/200
# 7/7 [==============================] - 0s 30ms/step - loss: 3.5124 - accuracy: 0.1324
# Epoch 31/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.4410 - accuracy: 0.1618
# Epoch 32/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.3705 - accuracy: 0.2255
# Epoch 33/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.2974 - accuracy: 0.2696
# Epoch 34/200
# 7/7 [==============================] - 0s 26ms/step - loss: 3.2326 - accuracy: 0.2010
# Epoch 35/200
# 7/7 [==============================] - 0s 27ms/step - loss: 3.1175 - accuracy: 0.2451
# Epoch 36/200
# 7/7 [==============================] - 0s 30ms/step - loss: 3.0623 - accuracy: 0.3333
# Epoch 37/200
# 7/7 [==============================] - 0s 27ms/step - loss: 2.9461 - accuracy: 0.3578
# Epoch 38/200
# 7/7 [==============================] - 0s 28ms/step - loss: 2.8562 - accuracy: 0.3529
# Epoch 39/200
# 7/7 [==============================] - 0s 28ms/step - loss: 2.7708 - accuracy: 0.3873
# Epoch 40/200
# 7/7 [==============================] - 0s 28ms/step - loss: 2.6751 - accuracy: 0.4412
# Epoch 41/200
# 7/7 [==============================] - 0s 27ms/step - loss: 2.5844 - accuracy: 0.4559
# Epoch 42/200
# 7/7 [==============================] - 0s 29ms/step - loss: 2.5052 - accuracy: 0.4804
# Epoch 43/200
# 7/7 [==============================] - 0s 29ms/step - loss: 2.4239 - accuracy: 0.4902
# Epoch 44/200
# 7/7 [==============================] - 0s 30ms/step - loss: 2.3381 - accuracy: 0.5392
# Epoch 45/200
# 7/7 [==============================] - 0s 29ms/step - loss: 2.2658 - accuracy: 0.5637
# Epoch 46/200
# 7/7 [==============================] - 0s 28ms/step - loss: 2.1886 - accuracy: 0.5882
# Epoch 47/200
# 7/7 [==============================] - 0s 26ms/step - loss: 2.1188 - accuracy: 0.6029
# Epoch 48/200
# 7/7 [==============================] - 0s 30ms/step - loss: 2.0392 - accuracy: 0.6520
# Epoch 49/200
# 7/7 [==============================] - 0s 29ms/step - loss: 1.9829 - accuracy: 0.6863
# Epoch 50/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.9186 - accuracy: 0.7059
# Epoch 51/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.8509 - accuracy: 0.6765
# Epoch 52/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.8005 - accuracy: 0.7059
# Epoch 53/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.7467 - accuracy: 0.7500
# Epoch 54/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.6892 - accuracy: 0.7745
# Epoch 55/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.6400 - accuracy: 0.7647
# Epoch 56/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.5952 - accuracy: 0.8088
# Epoch 57/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.5391 - accuracy: 0.8088
# Epoch 58/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.4971 - accuracy: 0.8039
# Epoch 59/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.4570 - accuracy: 0.8088
# Epoch 60/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.4109 - accuracy: 0.8235
# Epoch 61/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.3766 - accuracy: 0.8480
# Epoch 62/200
# 7/7 [==============================] - 0s 35ms/step - loss: 1.3305 - accuracy: 0.8480
# Epoch 63/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.2987 - accuracy: 0.8382
# Epoch 64/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.2591 - accuracy: 0.8480
# Epoch 65/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.2321 - accuracy: 0.8824
# Epoch 66/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.1931 - accuracy: 0.8824
# Epoch 67/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.1671 - accuracy: 0.8529
# Epoch 68/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.1365 - accuracy: 0.8235
# Epoch 69/200
# 7/7 [==============================] - 0s 28ms/step - loss: 1.0989 - accuracy: 0.8676
# Epoch 70/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.0722 - accuracy: 0.8873
# Epoch 71/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.0445 - accuracy: 0.8873
# Epoch 72/200
# 7/7 [==============================] - 0s 27ms/step - loss: 1.0178 - accuracy: 0.9069
# Epoch 73/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.9894 - accuracy: 0.8971
# Epoch 74/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.9642 - accuracy: 0.9069
# Epoch 75/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.9442 - accuracy: 0.8873
# Epoch 76/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.9228 - accuracy: 0.8824
# Epoch 77/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.8991 - accuracy: 0.9069
# Epoch 78/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.8830 - accuracy: 0.9069
# Epoch 79/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.8567 - accuracy: 0.9167
# Epoch 80/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.8391 - accuracy: 0.9118
# Epoch 81/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.8251 - accuracy: 0.9314
# Epoch 82/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.8055 - accuracy: 0.9216
# Epoch 83/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.7856 - accuracy: 0.9510
# Epoch 84/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.7659 - accuracy: 0.9510
# Epoch 85/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.7460 - accuracy: 0.9314
# Epoch 86/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.7291 - accuracy: 0.9363
# Epoch 87/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.7142 - accuracy: 0.9216
# Epoch 88/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.6972 - accuracy: 0.9559
# Epoch 89/200
# 7/7 [==============================] - 0s 37ms/step - loss: 0.6870 - accuracy: 0.9608
# Epoch 90/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6750 - accuracy: 0.9510
# Epoch 91/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.6586 - accuracy: 0.9461
# Epoch 92/200
# 7/7 [==============================] - 0s 33ms/step - loss: 0.6423 - accuracy: 0.9461
# Epoch 93/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.6272 - accuracy: 0.9461
# Epoch 94/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.6157 - accuracy: 0.9608
# Epoch 95/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.6049 - accuracy: 0.9608
# Epoch 96/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.5945 - accuracy: 0.9559
# Epoch 97/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.5821 - accuracy: 0.9461
# Epoch 98/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5631 - accuracy: 0.9559
# Epoch 99/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5587 - accuracy: 0.9461
# Epoch 100/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.5492 - accuracy: 0.9461
# Epoch 101/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.5403 - accuracy: 0.9608
# Epoch 102/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.5268 - accuracy: 0.9608
# Epoch 103/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.5166 - accuracy: 0.9608
# Epoch 104/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.5171 - accuracy: 0.9559
# Epoch 105/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.5024 - accuracy: 0.9608
# Epoch 106/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4888 - accuracy: 0.9608
# Epoch 107/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4796 - accuracy: 0.9657
# Epoch 108/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4741 - accuracy: 0.9657
# Epoch 109/200
# 7/7 [==============================] - 0s 36ms/step - loss: 0.4619 - accuracy: 0.9706
# Epoch 110/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4570 - accuracy: 0.9657
# Epoch 111/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4497 - accuracy: 0.9510
# Epoch 112/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4413 - accuracy: 0.9657
# Epoch 113/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4321 - accuracy: 0.9657
# Epoch 114/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4255 - accuracy: 0.9706
# Epoch 115/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4168 - accuracy: 0.9657
# Epoch 116/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4162 - accuracy: 0.9657
# Epoch 117/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4065 - accuracy: 0.9657
# Epoch 118/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4018 - accuracy: 0.9706
# Epoch 119/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3987 - accuracy: 0.9657
# Epoch 120/200
# 7/7 [==============================] - 0s 34ms/step - loss: 0.3870 - accuracy: 0.9657
# Epoch 121/200
# 7/7 [==============================] - 0s 36ms/step - loss: 0.3814 - accuracy: 0.9706
# Epoch 122/200
# 7/7 [==============================] - 0s 33ms/step - loss: 0.3822 - accuracy: 0.9657
# Epoch 123/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3754 - accuracy: 0.9657
# Epoch 124/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3654 - accuracy: 0.9657
# Epoch 125/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3578 - accuracy: 0.9706
# Epoch 126/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3486 - accuracy: 0.9657
# Epoch 127/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3443 - accuracy: 0.9755
# Epoch 128/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3407 - accuracy: 0.9755
# Epoch 129/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3351 - accuracy: 0.9755
# Epoch 130/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3351 - accuracy: 0.9559
# Epoch 131/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3302 - accuracy: 0.9657
# Epoch 132/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3260 - accuracy: 0.9657
# Epoch 133/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3216 - accuracy: 0.9608
# Epoch 134/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3203 - accuracy: 0.9706
# Epoch 135/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3102 - accuracy: 0.9755
# Epoch 136/200
# 7/7 [==============================] - 0s 35ms/step - loss: 0.3124 - accuracy: 0.9608
# Epoch 137/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3064 - accuracy: 0.9657
# Epoch 138/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3036 - accuracy: 0.9706
# Epoch 139/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2937 - accuracy: 0.9657
# Epoch 140/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2933 - accuracy: 0.9706
# Epoch 141/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2871 - accuracy: 0.9706
# Epoch 142/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2826 - accuracy: 0.9706
# Epoch 143/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2784 - accuracy: 0.9706
# Epoch 144/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2775 - accuracy: 0.9706
# Epoch 145/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2755 - accuracy: 0.9608
# Epoch 146/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2754 - accuracy: 0.9608
# Epoch 147/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2645 - accuracy: 0.9657
# Epoch 148/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2645 - accuracy: 0.9706
# Epoch 149/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2598 - accuracy: 0.9755
# Epoch 150/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2586 - accuracy: 0.9706
# Epoch 151/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2527 - accuracy: 0.9706
# Epoch 152/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2568 - accuracy: 0.9706
# Epoch 153/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2536 - accuracy: 0.9657
# Epoch 154/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2456 - accuracy: 0.9755
# Epoch 155/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2468 - accuracy: 0.9755
# Epoch 156/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2414 - accuracy: 0.9755
# Epoch 157/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2364 - accuracy: 0.9755
# Epoch 158/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2334 - accuracy: 0.9755
# Epoch 159/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2313 - accuracy: 0.9706
# Epoch 160/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.2273 - accuracy: 0.9706
# Epoch 161/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.2303 - accuracy: 0.9755
# Epoch 162/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2282 - accuracy: 0.9657
# Epoch 163/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2224 - accuracy: 0.9804
# Epoch 164/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2208 - accuracy: 0.9706
# Epoch 165/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2218 - accuracy: 0.9657
# Epoch 166/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2207 - accuracy: 0.9755
# Epoch 167/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2178 - accuracy: 0.9755
# Epoch 168/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2165 - accuracy: 0.9706
# Epoch 169/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2113 - accuracy: 0.9755
# Epoch 170/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2054 - accuracy: 0.9755
# Epoch 171/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2043 - accuracy: 0.9706
# Epoch 172/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2026 - accuracy: 0.9706
# Epoch 173/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1999 - accuracy: 0.9804
# Epoch 174/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1993 - accuracy: 0.9804
# Epoch 175/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1966 - accuracy: 0.9755
# Epoch 176/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1981 - accuracy: 0.9706
# Epoch 177/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1935 - accuracy: 0.9706
# Epoch 178/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1938 - accuracy: 0.9755
# Epoch 179/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1900 - accuracy: 0.9804
# Epoch 180/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1884 - accuracy: 0.9755
# Epoch 181/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1891 - accuracy: 0.9706
# Epoch 182/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1875 - accuracy: 0.9706
# Epoch 183/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1851 - accuracy: 0.9804
# Epoch 184/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1844 - accuracy: 0.9755
# Epoch 185/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1827 - accuracy: 0.9706
# Epoch 186/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1787 - accuracy: 0.9755
# Epoch 187/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1770 - accuracy: 0.9706
# Epoch 188/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1773 - accuracy: 0.9755
# Epoch 189/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1748 - accuracy: 0.9706
# Epoch 190/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1736 - accuracy: 0.9804
# Epoch 191/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1771 - accuracy: 0.9657
# Epoch 192/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1724 - accuracy: 0.9706
# Epoch 193/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1713 - accuracy: 0.9657
# Epoch 194/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1648 - accuracy: 0.9755
# Epoch 195/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1670 - accuracy: 0.9755
# Epoch 196/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1628 - accuracy: 0.9706
# Epoch 197/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1665 - accuracy: 0.9608
# Epoch 198/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1631 - accuracy: 0.9657
# Epoch 199/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1614 - accuracy: 0.9755
# Epoch 200/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1605 - accuracy: 0.9804

# %%
import matplotlib.pyplot as plt
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.show()

# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
try:
    user_input = input('Masukkan pertanyaan: ')
    user_input = ''.join([letters.lower() for letters in user_input if letters not in string.punctuation])
    texts_p = [user_input]
    
    prediction_input = tokenizer.texts_to_sequences(texts_p)
    prediction_input = pad_sequences(prediction_input, maxlen=input_shape)
    
    predicted_output = model.predict(prediction_input)
    predicted_label_index = np.argmax(predicted_output)
    predicted_label = label_encoder.inverse_transform([predicted_label_index])[0]
    
    print('Chatbot:', predicted_label)
except:
    print("Chatbot: Maaf, saya tidak memahami maksud Anda.")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Chatbot: PMS (Sindrom Pra-Menstruasi)

# %%
import random

while True:
    user_input = input('You: ')
    if user_input.lower() == 'goodbye':
        print("Chatbot: Goodbye!")
        break
    try:
        input_seq = tokenizer.texts_to_sequences([user_input])
        input_seq = pad_sequences(input_seq, maxlen=input_shape)
        predicted_label_seq = model.predict(input_seq)
        predicted_label = label_encoder.inverse_transform([predicted_label_seq.argmax(axis=-1)])[0]
        print("tags:", predicted_label)

        # Pilih respons dari kategori tag
        responses_for_tag = responses.get(predicted_label, ["I'm sorry, I don't understand that."])
        response = random.choice(responses_for_tag)
        
        print("Chatbot:", response)
    except:
        print("Chatbot: Maaf, saya tidak memahami maksud Anda.")
# Out:
# 1/1 [==============================] - 1s 535ms/step
# c:\Users\nurul\anaconda3\envs\cnn\lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# tags: PMS (Sindrom Pra-Menstruasi)
# Chatbot: PMS dapat mempengaruhi kesehatan mental. Beberapa gejala PMS yang dapat mempengaruhi kesehatan mental meliputi perubahan suasana hati, kecemasan, dan depresi. Jika Anda mengalami gejala PMS yang mempengaruhi kesehatan mental Anda, sebaiknya berkonsultasi dengan dokter.
# 1/1 [==============================] - 0s 19ms/step
# c:\Users\nurul\anaconda3\envs\cnn\lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# tags: menopause
# Chatbot: Menopause adalah kondisi di mana ovarium berhenti memproduksi hormon reproduksi dan menstruasi tidak terjadi selama 12 bulan berturut-turut[^1^][1]. Gejala umum dari menopause meliputi haid yang tidak teratur, hot flashes, insomnia, dan perubahan suasana hati[^1^][1].
# 1/1 [==============================] - 0s 28ms/step
# c:\Users\nurul\anaconda3\envs\cnn\lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# tags: Kram Perut
# Chatbot: Kram perut saat menstruasi dapat disebabkan oleh berbagai faktor, seperti ketidakseimbangan hormon, infeksi, atau kondisi medis tertentu. Jika Anda mengalami kram perut yang tidak normal, sebaiknya berkonsultasi dengan dokter.
# 1/1 [==============================] - 0s 18ms/step
# c:\Users\nurul\anaconda3\envs\cnn\lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# tags: PMS (Sindrom Pra-Menstruasi)
# Chatbot: Jika gejala PMS Anda parah dan mengganggu aktivitas sehari-hari Anda, sebaiknya berkonsultasi dengan dokter. Dokter dapat membantu menentukan penyebab gejala PMS Anda dan meresepkan pengobatan yang sesuai.

# %%
def predict_answer(model, tokenizer, label_encoder, question):
    question = ''.join([letters.lower() for letters in question if letters not in string.punctuation])
    texts_p = [question]
    prediction_input = tokenizer.texts_to_sequences(texts_p)
    prediction_input = np.array(prediction_input).reshape(-1)
    prediction_input = pad_sequences([prediction_input], input_shape)
    output = model.predict(prediction_input)
    output = output.argmax()
    response_tag = label_encoder.inverse_transform([output])[0]
    return response_tag

# %%
import random
while True:
    
    user_input = input('You: ')
    if user_input.lower() == 'goodbye':
        print("Chatbot: Goodbye!")
        break

    # Use your predict_answer function to get the response
    response_tag = predict_answer(model, tokenizer, label_encoder, user_input)

    print("Chatbot:", random.choice(responses.get(response_tag, ["I'm sorry, I don't understand that."])))
# Out:
# 1/1 [==============================] - 0s 325ms/step
# Chatbot: Menstruasi adalah proses alami yang terjadi pada wanita setiap bulan. Selama menstruasi, tubuh melepaskan lapisan rahim yang tidak diperlukan melalui vagina.
# 1/1 [==============================] - 0s 17ms/step
# Chatbot: Menstruasi adalah proses alami yang terjadi pada wanita setiap bulan. Selama menstruasi, tubuh melepaskan lapisan rahim yang tidak diperlukan melalui vagina.
# 1/1 [==============================] - 0s 16ms/step
# Chatbot: Menstrual cup adalah alat penampung darah menstruasi yang dapat digunakan berulang kali. Berikut adalah panduan penggunaan menstrual cup:
#
# 1. Cuci tangan dengan sabun dan air mengalir.
# 2. Oleskan air atau pelumas berbahan dasar air ke tepi gelas.
# 3. Lipat dengan kuat cangkir menstruasi menjadi dua, pegang di satu tangan dengan tepi menghadap ke atas.
# 4. Masukkan cangkir, pelek ke atas, ke dalam vagina seperti Anda akan memasukkan tampon tanpa aplikator.
# 5. Setelah cangkir berada di dalam vagina, lepaskan jari Anda dari cangkir dan biarkan cangkir membuka sendiri.
# 6. Untuk melepas cangkir, tarik perlahan pada peleknya dan tekan bagian bawah cangkir untuk melepaskan vakum [^1^][1] [^2^][2] [^3^][3].
# 1/1 [==============================] - 0s 20ms/step
# Chatbot: Menstrual cup aman digunakan jika digunakan dengan benar dan steril. Menstrual cup juga dapat membantu mengurangi jumlah sampah yang dihasilkan selama menstruasi [^1^][1].
